# %% [markdown]
# # Анализ оттока клиентов банка "Метанпром"

# %% [markdown]
# **Материалы:**<br>
# Презентация: https://drive.google.com/file/d/1j6JwoKqcFUoSQgUSGnTokjF-zaHbtfaE/view?usp=sharing

# %% [markdown]
# **Описание проекта:**<br>
# <br>
# Заказчик — банк «Метанпром». Нужно проверить, влияет ли доход клиента на уход из банка. Входные данные от банка — статистика о платёжеспособности клиентов.<br>

# %% [markdown]
# **Цель проекта** -
# - проанализировать клиентов регионального банка;
# - выделить портрет клиентов,которые склонны уходить из банка;
# - проверить гипотезы о различии параметров клиентов (ушедших и оставшихся);
# - дать рекомендации менеджеру продукта для разработки мер по удержанию.

# %% [markdown]
# **Описание данных**<br>
# <br>
# Датасет содержит данные о клиентах банка «Метанпром». Банк располагается в Ярославле и областных городах: Ростов Великий и Рыбинск.<br>
# <br>
# Колонки:<br>
# <br>
# `userid` — идентификатор пользователя,<br>
# `score` — баллы кредитного скоринга,<br>
# `City` — город,<br>
# `Gender` — пол,<br>
# `Age` — возраст,<br>
# `Objects` — количество объектов в собственности,<br>
# `Balance` — баланс на счёте,<br>
# `Products` — количество продуктов, которыми пользуется клиент,<br>
# `CreditCard` — есть ли кредитная карта,<br>
# `Loyalty` — активный клиент,<br>
# `estimated_salary` — заработная плата клиента,<br>
# `Churn` — ушёл или нет.<br>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-изучение-общей-информации" data-toc-modified-id="Загрузка-данных-и-изучение-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и изучение общей информации</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Исследовательский-анализ-данных-(EDA)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#Столбец-score" data-toc-modified-id="Столбец-score-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Столбец <code>score</code></a></span></li><li><span><a href="#Столбец-city" data-toc-modified-id="Столбец-city-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Столбец <code>city</code></a></span></li><li><span><a href="#Столбец-gender" data-toc-modified-id="Столбец-gender-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Столбец <code>gender</code></a></span></li><li><span><a href="#Столбец-age" data-toc-modified-id="Столбец-age-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Столбец <code>age</code></a></span></li><li><span><a href="#Столбец-objects" data-toc-modified-id="Столбец-objects-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Столбец <code>objects</code></a></span></li><li><span><a href="#Столбец-balance" data-toc-modified-id="Столбец-balance-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Столбец <code>balance</code></a></span></li><li><span><a href="#Столбец-products" data-toc-modified-id="Столбец-products-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Столбец <code>products</code></a></span></li><li><span><a href="#Столбец-credit_card" data-toc-modified-id="Столбец-credit_card-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Столбец <code>credit_card</code></a></span></li><li><span><a href="#Столбец-loyalty" data-toc-modified-id="Столбец-loyalty-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Столбец <code>loyalty</code></a></span></li><li><span><a href="#Столбец-estimated_salary" data-toc-modified-id="Столбец-estimated_salary-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Столбец <code>estimated_salary</code></a></span></li><li><span><a href="#Столбец-churn" data-toc-modified-id="Столбец-churn-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Столбец <code>churn</code></a></span></li><li><span><a href="#Изучение-пропусков" data-toc-modified-id="Изучение-пропусков-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Изучение пропусков</a></span></li><li><span><a href="#Фильтрация-данных-от-выбросов" data-toc-modified-id="Фильтрация-данных-от-выбросов-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Фильтрация данных от выбросов</a></span></li><li><span><a href="#Категоризация-пользователей-(по-возрастным-группам,-заработной-плате-и-по-баллам-кредитного-скоринга)" data-toc-modified-id="Категоризация-пользователей-(по-возрастным-группам,-заработной-плате-и-по-баллам-кредитного-скоринга)-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Категоризация пользователей (по возрастным группам, заработной плате и по баллам кредитного скоринга)</a></span></li></ul></li><li><span><a href="#Cформируем-портреты-клиентов" data-toc-modified-id="Cформируем-портреты-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Cформируем портреты клиентов</a></span><ul class="toc-item"><li><span><a href="#Матрица-корреляций" data-toc-modified-id="Матрица-корреляций-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Матрица корреляций</a></span></li><li><span><a href="#Парные-графики-зависимостей-переменных-по-оттоку" data-toc-modified-id="Парные-графики-зависимостей-переменных-по-оттоку-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Парные графики зависимостей переменных по оттоку</a></span></li><li><span><a href="#Построим-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)" data-toc-modified-id="Построим-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)</a></span></li><li><span><a href="#Портрет-клиента,-склонного-к-оттоку" data-toc-modified-id="Портрет-клиента,-склонного-к-оттоку-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Портрет клиента, склонного к оттоку</a></span></li><li><span><a href="#Портрет-&quot;хорошего&quot;-клиента" data-toc-modified-id="Портрет-&quot;хорошего&quot;-клиента-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Портрет "хорошего" клиента</a></span></li></ul></li><li><span><a href="#Проверка-статистических-гипотез" data-toc-modified-id="Проверка-статистических-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка статистических гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-№-1:-Зарплата-клиентов,-которые-ушли-в-отток-и-тех-кто-остался-различна" data-toc-modified-id="Гипотеза-№-1:-Зарплата-клиентов,-которые-ушли-в-отток-и-тех-кто-остался-различна-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Гипотеза № 1: Зарплата клиентов, которые ушли в отток и тех кто остался различна</a></span></li><li><span><a href="#Гипотеза-№-2:-Доли-оттока-клиентов-в-группах,-имеющих-1-и-2-продукта,-различаются" data-toc-modified-id="Гипотеза-№-2:-Доли-оттока-клиентов-в-группах,-имеющих-1-и-2-продукта,-различаются-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Гипотеза № 2: Доли оттока клиентов в группах, имеющих 1 и 2 продукта, различаются</a></span></li><li><span><a href="#Гипотеза-№3:-Возраст-клиентов,-которые-ушли-в-отток-и-тех,-кто-остался-различен" data-toc-modified-id="Гипотеза-№3:-Возраст-клиентов,-которые-ушли-в-отток-и-тех,-кто-остался-различен-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Гипотеза №3: Возраст клиентов, которые ушли в отток и тех, кто остался различен</a></span></li><li><span><a href="#Гипотеза-№-4:-Баллы-кредитного-скоринга-клиентов,-которые-ушли-в-отток-и-тех,-кто-остался-различны" data-toc-modified-id="Гипотеза-№-4:-Баллы-кредитного-скоринга-клиентов,-которые-ушли-в-отток-и-тех,-кто-остался-различны-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Гипотеза № 4: Баллы кредитного скоринга клиентов, которые ушли в отток и тех, кто остался различны</a></span></li><li><span><a href="#Гипотеза-№-5:-Доли-мужчин-и-женщин,-ушедших-в-отток-и-оставшихся-различаются" data-toc-modified-id="Гипотеза-№-5:-Доли-мужчин-и-женщин,-ушедших-в-отток-и-оставшихся-различаются-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Гипотеза № 5: Доли мужчин и женщин, ушедших в отток и оставшихся различаются</a></span></li><li><span><a href="#Гипотеза-№-6:-Баланс-на-счете-клиентов,-которые-ушли-в-отток-и-тех,-кто-остался-различен" data-toc-modified-id="Гипотеза-№-6:-Баланс-на-счете-клиентов,-которые-ушли-в-отток-и-тех,-кто-остался-различен-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Гипотеза № 6: Баланс на счете клиентов, которые ушли в отток и тех, кто остался различен</a></span></li><li><span><a href="#Гипотеза-№7:Доли-активных-клиентов,-которые-ушли-в-отток-и-тех,-кто-остался-различаются" data-toc-modified-id="Гипотеза-№7:Доли-активных-клиентов,-которые-ушли-в-отток-и-тех,-кто-остался-различаются-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Гипотеза №7:Доли активных клиентов, которые ушли в отток и тех, кто остался различаются</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Базовые-рекомендации-по-работе-с-клиентами" data-toc-modified-id="Базовые-рекомендации-по-работе-с-клиентами-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Базовые рекомендации по работе с клиентами</a></span></li></ul></div>

# %% [markdown]
# ## Загрузка данных и изучение общей информации

# %% [markdown]
# Импортируем библиотеки

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
from scipy.stats import mannwhitneyu as mwu
from  scipy.stats import chi2_contingency

import warnings
warnings.filterwarnings("ignore")

# %%
pd.options.display.float_format = '{:,.2f}'.format
sns.set_style('whitegrid')

# %%
#Функция вычисления долей по оттоку, вывод результата в виде датафрайма
def check_ratio(col):
    a = df.groupby([col,'churn'])['user_id'].count().rename("ratio")
    b = a /a.groupby(level=0).sum() 
    dfs = pd.DataFrame(data=b)
    return dfs
        
# Функция проверки статзначимости гипотез критерием Манна-Уитни
def mwu_test(alpha, col):
    churn_ = df[df['churn']==1]
    good = df[df['churn']==0]
    alpha = alpha
    results = mwu(churn_[col], good[col])
    print('p-значение:', results.pvalue)
    if results.pvalue < alpha:
        print("Отвергаем нулевую гипотезу")
    else:
        print("Не получилось отвергнуть нулевую гипотезу")  

# Функция проверки статзначимости гипотез качественных переменных критерием хи-квадрат
def chi2(alpha, col):
    a = df.groupby([col,'churn'])['user_id'].count()
    alpha=alpha
    kf_data = np.array([[a.loc[0,0], a.loc[0,1]], [a.loc[1,0], a.loc[1,1]]])
    kf = chi2_contingency(kf_data)
    print('p-значение:', kf[1])
    if kf[1] < alpha:
        print("Отвергаем нулевую гипотезу")
    else:
        print("Не получилось отвергнуть нулевую гипотезу")

# %% [markdown]
# Прочитаем файлы с данными

# %%
df = pd.read_csv('./datasets/bank_dataset.csv', sep = ',')

# %% [markdown]
# Посмотрим на наш датасет и общую информацию

# %%
df.head(1)
# Out:
#      userid  score       City Gender  Age  Objects  Balance  Products  \
# 0  15677338    619  Ярославль      Ж   42        2      NaN         1
#
#    CreditCard  Loyalty  estimated_salary  Churn
# 0           1        1        101,348.88      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   userid            10000 non-null  int64
#  1   score             10000 non-null  int64
#  2   City              10000 non-null  object
#  3   Gender            10000 non-null  object
#  4   Age               10000 non-null  int64
#  5   Objects           10000 non-null  int64
#  6   Balance           6383 non-null   float64
#  7   Products          10000 non-null  int64
#  8   CreditCard        10000 non-null  int64
#  9   Loyalty           10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  Churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# **Вывод:** Требуется провести подготовку данных: переименовать столбцы, пропуски столбца `balance` заполнять не будем.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Заменим названия столбцов на удобные

# %%
df.columns = df.columns.str.lower()
df.head(1)
# Out:
#      userid  score       city gender  age  objects  balance  products  \
# 0  15677338    619  Ярославль      Ж   42        2      NaN         1
#
#    creditcard  loyalty  estimated_salary  churn
# 0           1        1        101,348.88      1

# %%
df.rename(columns = {'userid':'user_id', 'creditcard':'credit_card'}, inplace = True)
df.head(1)
# Out:
#     user_id  score       city gender  age  objects  balance  products  \
# 0  15677338    619  Ярославль      Ж   42        2      NaN         1
#
#    credit_card  loyalty  estimated_salary  churn
# 0            1        1        101,348.88      1

# %% [markdown]
# Проверим на пропуски и дубликаты

# %%
df.isna().mean()
# Out:
# user_id            0.00
# score              0.00
# city               0.00
# gender             0.00
# age                0.00
# objects            0.00
# balance            0.36
# products           0.00
# credit_card        0.00
# loyalty            0.00
# estimated_salary   0.00
# churn              0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['user_id'].nunique()
# Out:
# 10000

# %%
df.describe().T
# Out:
#                      count          mean       std           min  \
# user_id          10,000.00 15,733,676.57 71,936.19 15,608,437.00
# score            10,000.00        650.53     96.65        350.00
# age              10,000.00         38.92     10.49         18.00
# objects          10,000.00          5.01      2.89          0.00
# balance           6,383.00    119,827.49 30,095.06      3,768.69
# products         10,000.00          1.53      0.58          1.00
# credit_card      10,000.00          0.71      0.46          0.00
# loyalty          10,000.00          0.52      0.50          0.00
# estimated_salary 10,000.00    100,090.24 57,510.49         11.58
# churn            10,000.00          0.20      0.40          0.00
#
#                            25%           50%           75%           max
# user_id          15,671,264.25 15,733,474.00 15,795,969.75 15,858,426.00
# score                   584.00        652.00        718.00        850.00
# ...

# %% [markdown]
# **Вывод:** Переименованы столбцы, датасет проверен на пропуски (выявлено 3617 пропусков (36%)в столбце баланс) и дубликаты, выведена общая информация о датасете. Предоставлены данные о 10000 уникальных клиентах банка.

# %% [markdown]
# Посмотрим распределение клиентов по оттоку

# %%
df.churn.value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8,4))
plt.legend(["Остался с банком", 'Ушёл от банка'], fontsize=8, facecolor='w')
plt.title('Распределение пользователей')
plt.tight_layout()
plt.axis('off');

# %% [markdown]
# По первому этапу знакомства с данными можно сделать вывод, что:<br>
# - в выборке представлены клиенты, где у 79.6% - остались с банком, а 20.4% ушли от банка, что говорит нам о том, что данные несбалансированы;<br>
# - пропущенные значения лежат в столбце `balance`, которые заменим отрицательным значением позже;<br>
# - клиентами банка являются жители городов Ярославля (50% в выборке), Рыбинска (25%) и Ростова Великого (25%);<br>
# - признаки в столбце `user_id` не несет никакой информации;<br>
# - клиенты банка имеют от 1 до 4 продуктов;<br>
# - в столбце `score` распределены люди с разным уровнем кредитного рейтинга, но в среднем имеют хорошую оценку.

# %% [markdown]
# ## Исследовательский анализ данных (EDA)

# %% [markdown]
# Рассмотрим данные каждого столбца, построим гистограммы, изучим влияние переменных на отток.

# %% [markdown]
# ### Столбец `score`

# %%
df['score'].value_counts()
# Out:
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 404      1
# 351      1
# 365      1
# 417      1
# 419      1
# Name: score, Length: 460, dtype: int64

# %%
df['score'].hist(bins=20)
plt.title('Распределение баллов кредитного скоринга')
plt.xlabel('баллы кредитного скоринга ')
plt.ylabel('количество клиентов');

# %% [markdown]
# Распределение близко к нормальному, только есть небольшой хвост слева (score<400) и одно выдающееся значение справа.

# %%
df.groupby ('score')['churn'].mean().plot(figsize=(20, 8), grid = True)
plt.title('Влияние баллов кредитного скоринга на отток')
plt.xlabel('Баллы кредитного скоринга')
plt.ylabel('churn');

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.histplot(data=df, x='score',hue='churn', kde=True,bins=50, ax=ax)
plt.title('Распределение клиентов по кредитным баллам')
plt.xlabel('Кредитные баллы')
plt.ylabel('Количество клиентов');

# %% [markdown]
# Клиенты у которых score<400 уходят в отток. У остальных среднее значение примерно 0,2

# %% [markdown]
# ### Столбец `city`

# %%
df['city'].value_counts()
# Out:
# Ярославль         5014
# Ростов Великий    2509
# Рыбинск           2477
# Name: city, dtype: int64

# %%
df.groupby ('city')['churn'].mean().plot(kind = 'bar', rot = 0)
plt.title('Отток по city')
plt.xlabel('city')
plt.ylabel('churn');

# %% [markdown]
# Для этого посмотрим на доли ушедших и оставшихся пользователей в каждом городе.

# %%
check_ratio('city')
# Out:
#                       ratio
# city           churn
# Ростов Великий 0       0.68
#                1       0.32
# Рыбинск        0       0.83
#                1       0.17
# Ярославль      0       0.84
#                1       0.16

# %% [markdown]
# В Рыбинске и Ярославле дела обстоят примерно одинаково, а вот в Ростове Великом % ушедших выше, чем в других городах практически в 2 раза и практически в 1,5 раза больше, чем по всему датасету. Стоит обратить внимание на этот параметр.

# %% [markdown]
# ### Столбец `gender`

# %%
df['gender'].value_counts()
# Out:
# М    5457
# Ж    4543
# Name: gender, dtype: int64

# %% [markdown]
# Присвоим мужчинам значение "1", а женщинам - "0"

# %%
df['gender'] = (df['gender'].isin(['М']))*1
df['gender'].value_counts()
# Out:
# 1    5457
# 0    4543
# Name: gender, dtype: int64

# %%
df.groupby ('gender')['churn'].mean().plot(kind = 'bar', rot =0)
plt.title('Отток по gender')
plt.xlabel('gender')
plt.ylabel('churn');

# %%
check_ratio('gender')
# Out:
#               ratio
# gender churn
# 0      0       0.75
#        1       0.25
# 1      0       0.84
#        1       0.16

# %% [markdown]
#  Женщины больше склонны к оттоку (25%), чем мужчины (16%).Разница всего 9%.

# %% [markdown]
# ### Столбец `age`

# %%
df['age'].hist(bins = 80)
plt.title('Распределение клиентов по возрасту')
plt.xlabel('Возраст')
plt.ylabel('Количество клиентов');

# %% [markdown]
# Распределение близко к нормальному с тяжелым правым хвостом

# %% [markdown]
# В данном датасете больше 400 клиентов каждого возраста в диапазоне 31-41 год, а менее 100 клиентов в возрастных диапазонах 18-24, 53-92

# %%
df.groupby ('age')['churn'].mean().plot()
plt.title('Отток по age')
plt.xlabel('age')
plt.ylabel('churn');

# %% [markdown]
# На графике видно, что самый большой отток в возрасте 55 лет, клиенты  от 75 лет не уходят( но есть один выброс).

# %%
fig, ax = plt.subplots(figsize=(16,8))
sns.histplot(data=df, x='age',hue='churn', kde=True, bins=74, ax=ax)
plt.title('Распределение возраста')
plt.xlabel('Возраст')
plt.ylabel('Количество клиентов');

# %% [markdown]
# В интервале возрастов 49-59 лет количество клиентов, ушедших в оттток, превышает число клиентов, оставшихся с банком. Вероятнее всего, большинство клиентов банка - зарплатные клиенты и уходят из банка при выходе на пенсию.

# %% [markdown]
# ### Столбец `objects`

# %%
df['objects'].value_counts(ascending = False)
# Out:
# 2     1048
# 1     1035
# 7     1028
# 8     1025
# 5     1012
# 3     1009
# 4      989
# 9      984
# 6      967
# 10     490
# 0      413
# Name: objects, dtype: int64

# %%
df['objects'].hist(edgecolor = "black")
plt.title('Распределение клиентов по objects')
plt.xlabel('objects')
plt.ylabel('Количество клиентов');

# %%
df.groupby ('objects')['churn'].mean().plot()
plt.title('Отток по objects')
plt.xlabel('objects')
plt.ylabel('churn');

# %%
check_ratio('objects')
# Out:
#                ratio
# objects churn
# 0       0       0.77
#         1       0.23
# 1       0       0.78
#         1       0.22
# 2       0       0.81
#         1       0.19
# 3       0       0.79
#         1       0.21
# 4       0       0.79
#         1       0.21
# 5       0       0.79
#         1       0.21
# 6       0       0.80
#         1       0.20
# 7       0       0.83
#         1       0.17
# 8       0       0.81
#         1       0.19
# 9       0       0.78
#         1       0.22
# 10      0       0.79
#         1       0.21

# %% [markdown]
# Разница оттока клиентов с отсутствующим объектом недвижимости (23%) и  с 7-ью объектами недвижимости (17%) составляет 6%.

# %% [markdown]
# ### Столбец `balance`

# %% [markdown]
# Для дальнейшего упрощения анализа данных предположим, что balance - это дебетовый счет

# %% [markdown]
# Без детального анализа пропусков невозможно решить, как их обработать правильно. Поэтому на 1 этапе заменим значение "NaN" на маркер отсутствующего значения "-9999", чтобы увидеть пропущенные значения на графике и на выводе общей информации (на сколько влияют отсутствующие значения на общее распределение).

# %%
df['balance'] = df['balance'].fillna(-9999)

# %%
nan=df.query('balance==-9999')

# %%
def check_ratio_2(col):
    a = nan.groupby([col,'churn'])['user_id'].count().rename("ratio")
    b = a /a.groupby(level=0).sum() 
    dfs = pd.DataFrame(data=b)
    return dfs

# %%
check_ratio_2('balance')
# Out:
#                  ratio
# balance   churn
# -9,999.00 0       0.86
#           1       0.14

# %% [markdown]
# С отсутствующим балансом 86 % клиентов остались в банке, а всего 14% ушли в отток. По таким данным судить сложно. Проведем детальный анализ пропусков после анализа всех столбцов датасета.

# %%
df['balance'].hist(bins = 20)
plt.title('Распределение баланса клиентов')
plt.xlabel('Баланс на счете, руб.')
plt.ylabel('Количество клиентов');

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.histplot(data=df, x='balance',hue='churn', kde=True, bins=50, ax=ax)
plt.title('Распределение клиентов по балансу')
plt.xlabel('Баланс клиентов')
plt.ylabel('Количество клиентов');

# %% [markdown]
# График малоинформативен, требуется дополнительное изучение данных.

# %% [markdown]
# ### Столбец `products`

# %%
df['products'].value_counts()
# Out:
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: products, dtype: int64

# %%
df['products'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Клиенты, имеющие 1 и 2 продукта доминируют. С учетом допущения, что balance -дебетовый счет, можно предположить, что второй продукт-кредитная или зарплатная карта. Другими продуктами могут быть ипотека(кредит), вклад.

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.histplot(data=df, x='products',hue='churn', kde=True, bins=10, ax=ax)
plt.title('Распределение объектов')
plt.xlabel('Количество продуктов')
plt.ylabel('Количество клиентов');

# %% [markdown]
# Количество ушедших клиентов, имеющих 3-4 продукта, превышает количество оставшихся клиентов.

# %%
check_ratio('products')
# Out:
#                 ratio
# products churn
# 1        0       0.72
#          1       0.28
# 2        0       0.92
#          1       0.08
# 3        0       0.17
#          1       0.83
# 4        1       1.00

# %% [markdown]
# Клиенты с 2 продуктами меньше всего склонны к оттоку.

# %% [markdown]
# ### Столбец `credit_card`

# %%
df['credit_card'].value_counts()
# Out:
# 1    7055
# 0    2945
# Name: credit_card, dtype: int64

# %%
df.groupby ('credit_card')['churn'].mean().plot(kind = 'bar', rot = 0)
plt.title('Отток по credit_card')
plt.xlabel('credit_card')
plt.ylabel('churn');

# %%
check_ratio('credit_card')
# Out:
#                    ratio
# credit_card churn
# 0           0       0.79
#             1       0.21
# 1           0       0.80
#             1       0.20

# %% [markdown]
# Разница оттока между клиентами имеющими кредитную карту(20%) и не имеющими кредитную карту(21%) составляет всего 1%.

# %% [markdown]
# ### Столбец `loyalty`

# %%
df['loyalty'].value_counts()
# Out:
# 1    5151
# 0    4849
# Name: loyalty, dtype: int64

# %%
df.groupby ('loyalty')['churn'].mean().plot(kind = 'bar', rot = 0)
plt.title('Отток по loyalty')
plt.xlabel('loyalty')
plt.ylabel('churn');

# %%
check_ratio('loyalty')
# Out:
#                ratio
# loyalty churn
# 0       0       0.73
#         1       0.27
# 1       0       0.86
#         1       0.14

# %% [markdown]
# Разница оттока между активными клиентами (14%) и не активными клиентами (27%) составляет 13%.

# %% [markdown]
# ### Столбец `estimated_salary`

# %%
df['estimated_salary'].hist(bins=50, figsize = (16, 6))
plt.title('Распределение зарплаты клиентов')
plt.xlabel('Заработная плата клиента, руб.')
plt.ylabel('Количество клиентов')
plt.ylim (170, 240);

# %%
df.boxplot('estimated_salary')
plt.title('Распределение заработной платы');

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.histplot(data=df, x='estimated_salary',hue='churn', kde=True,bins=50, ax=ax)
plt.title('Распределение клиентов по заработной плате')
plt.xlabel('Заработная плата клиентов, руб.')
plt.ylabel('Количество клиентов');

# %% [markdown]
# Средняя заработная плата равна 100000 руб., первый квартиль = 50000 руб., 3 квартиль = 150000 руб. Поэтому требуется категоризация клиентов по квартилям заработной платы.

# %% [markdown]
# ### Столбец `churn`

# %%
df['churn'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: churn, dtype: int64

# %% [markdown]
# 2037 клиентов ушли в отток

# %% [markdown]
# ### Изучение пропусков

# %%
nan.describe(include=['object'])
# Out:
#              city
# count        3617
# unique          2
# top     Ярославль
# freq         2418

# %%
df['city'].value_counts()
# Out:
# Ярославль         5014
# Ростов Великий    2509
# Рыбинск           2477
# Name: city, dtype: int64

# %%
nan['city'].value_counts()
# Out:
# Ярославль    2418
# Рыбинск      1199
# Name: city, dtype: int64

# %%
nan['gender'].value_counts()
# Out:
# 1    1963
# 0    1654
# Name: gender, dtype: int64

# %%
nan['products'].value_counts()
# Out:
# 2    2600
# 1     905
# 3      98
# 4      14
# Name: products, dtype: int64

# %%
nan['credit_card'].value_counts()
# Out:
# 1    2592
# 0    1025
# Name: credit_card, dtype: int64

# %%
nan['loyalty'].value_counts()
# Out:
# 1    1873
# 0    1744
# Name: loyalty, dtype: int64

# %%
nan['churn'].value_counts()
# Out:
# 0    3117
# 1     500
# Name: churn, dtype: int64

# %% [markdown]
# При рассмотрении данных, где нет данных о балансе, выявлено, что в Ростове Великом таких записей нет, а доли пропусков в Ярославле и Рыбинске практически равны и составляют 48,2% и 48,4% соответственно. Сравним общую информацию по городам.

# %%
nan_yar=nan.query('city=="Ярославль"')
nan_yar.describe()
# Out:
#             user_id    score   gender      age  objects   balance  products  \
# count      2,418.00 2,418.00 2,418.00 2,418.00 2,418.00  2,418.00  2,418.00
# mean  15,734,278.93   648.35     0.54    38.40     5.06 -9,999.00      1.78
# std       72,073.61    96.89     0.50    10.52     2.87      0.00      0.50
# min   15,608,542.00   350.00     0.00    18.00     0.00 -9,999.00      1.00
# 25%   15,671,495.50   581.00     0.00    31.00     3.00 -9,999.00      1.00
# 50%   15,736,190.00   651.00     1.00    37.00     5.00 -9,999.00      2.00
# 75%   15,796,050.75   716.00     1.00    43.00     7.00 -9,999.00      2.00
# max   15,857,995.00   850.00     1.00    85.00    10.00 -9,999.00      4.00
#
#        credit_card  loyalty  estimated_salary    churn
# count     2,418.00 2,418.00          2,418.00 2,418.00
# mean          0.72     0.52         99,119.89     0.14
# std           0.45     0.50         57,758.76     0.35
# min           0.00     0.00             90.07     0.00
# ...

# %%
nan_yar['credit_card'].value_counts()
# Out:
# 1    1740
# 0     678
# Name: credit_card, dtype: int64

# %%
nan_yar['products'].value_counts()
# Out:
# 2    1739
# 1     610
# 3      57
# 4      12
# Name: products, dtype: int64

# %%
nan_yar['churn'].value_counts()
# Out:
# 0    2081
# 1     337
# Name: churn, dtype: int64

# %%
nan_yar.boxplot('products')
# Out:
# <AxesSubplot:>

# %%
nan_r=nan.query('city=="Рыбинск"')
nan_r.describe()
# Out:
#             user_id    score   gender      age  objects   balance  products  \
# count      1,199.00 1,199.00 1,199.00 1,199.00 1,199.00  1,199.00  1,199.00
# mean  15,735,505.69   651.69     0.55    38.50     5.09 -9,999.00      1.79
# std       71,715.49    94.68     0.50    10.44     2.85      0.00      0.49
# min   15,608,442.00   382.00     0.00    18.00     0.00 -9,999.00      1.00
# 25%   15,674,306.50   585.00     0.00    32.00     3.00 -9,999.00      2.00
# 50%   15,735,727.00   650.00     1.00    37.00     5.00 -9,999.00      2.00
# 75%   15,796,531.50   717.00     1.00    43.00     8.00 -9,999.00      2.00
# max   15,858,100.00   850.00     1.00    88.00    10.00 -9,999.00      4.00
#
#        credit_card  loyalty  estimated_salary    churn
# count     1,199.00 1,199.00          1,199.00 1,199.00
# mean          0.71     0.51         98,708.62     0.14
# std           0.45     0.50         57,697.57     0.34
# min           0.00     0.00            417.41     0.00
# ...

# %%
nan_r['products'].value_counts()
# Out:
# 2    861
# 1    295
# 3     41
# 4      2
# Name: products, dtype: int64

# %%
nan_r.boxplot('products');

# %%
nan_r['churn'].value_counts()
# Out:
# 0    1036
# 1     163
# Name: churn, dtype: int64

# %%
no_nan=df.query('balance > 0')
no_nan.describe()
# Out:
#             user_id    score   gender      age  objects    balance  products  \
# count      6,383.00 6,383.00 6,383.00 6,383.00 6,383.00   6,383.00  6,383.00
# mean  15,733,104.80   651.14     0.55    39.20     4.98 119,827.49      1.39
# std       71,929.13    96.93     0.50    10.48     2.91  30,095.06      0.58
# min   15,608,437.00   350.00     0.00    18.00     0.00   3,768.69      1.00
# 25%   15,670,940.00   584.00     0.00    32.00     2.00 100,181.98      1.00
# 50%   15,732,262.00   652.00     1.00    38.00     5.00 119,839.69      1.00
# 75%   15,795,842.00   718.00     1.00    44.00     8.00 139,512.29      2.00
# max   15,858,426.00   850.00     1.00    92.00    10.00 250,898.09      4.00
#
#        credit_card  loyalty  estimated_salary    churn
# count     6,383.00 6,383.00          6,383.00 6,383.00
# mean          0.70     0.51        100,717.35     0.24
# std           0.46     0.50         57,380.32     0.43
# ...

# %% [markdown]
# Сравним общую информацию о клиентах (без пропусков в балансе  и с пропусками):<br>
# 1 квартиль: <br>
# нет пропусков - в среднем 2 объекта недвижимости и 1 продукт, <br>
# пропуски - Рыбинск -  3 объекта недвижимости и 2 продукта, Ярославль - 3 объекта недвижимости и 1 продукт;<br>
# 2 квартиль (медиана): <br>
# нет пропусков - в среднем 5 объектов недвижимости и 1 продукт,<br>
# пропуски - 5 объектов недвижимости и 2 продукта.

# %% [markdown]
# **Вывод:** Наиболее вероятной причиной наличия пропусков в столбце `balance` является наличие "особого" банковского продукта, который позволяет не указывать (скрывать) баланс на счете клиента. Или связано с особенностями выгрузки данных: Ростов Великий-маленький город (30 тыс. чел) с, вероятно небольшим количеством отделений банка, а Ярославль и Рыбинск больше, население составляет 594 тыс.чел. и 197 тыс.чел. и, скорее всего, выгрузка данных клинтов из этих городов производится чаще, в несколько приемов. В одну из выгрузок и "пропали(забыли выгрузить)" данные о балансе.

# %% [markdown]
# ### Фильтрация данных от выбросов

# %% [markdown]
# При изучении общей информации о данных заметен большой разброс значений между минимальным значением и 1 квартилем в столбце
# `score` и между 3 квартилем и максимальным значением в столбце `age`. В связи с тем, что распределения этих параметров не подчиняются закону нормального распределения, проведем фильтрацию данных вручную.

# %% [markdown]
# Удалим данные о клиентах со score меньше 400 (левый хвост распределения параметра score) и возрастом старше 65 лет(правый хвост распределения параметра age)

# %%
 df=df.query('(score >= 400) & (age <= 65)')

# %% [markdown]
# Посмотрим общую информацию после очистки данных

# %%
df.describe().T
# Out:
#                     count          mean       std           min           25%  \
# user_id          9,717.00 15,733,620.49 71,872.06 15,608,437.00 15,671,044.00
# score            9,717.00        650.71     95.91        401.00        584.00
# gender           9,717.00          0.55      0.50          0.00          0.00
# age              9,717.00         38.03      9.12         18.00         32.00
# objects          9,717.00          5.01      2.89          0.00          3.00
# balance          9,717.00     72,986.57 66,845.50     -9,999.00     -9,999.00
# products         9,717.00          1.53      0.58          1.00          1.00
# credit_card      9,717.00          0.71      0.46          0.00          0.00
# loyalty          9,717.00          0.51      0.50          0.00          0.00
# estimated_salary 9,717.00    100,040.00 57,517.52         11.58     50,911.41
# churn            9,717.00          0.20      0.40          0.00          0.00
#
# ...

# %% [markdown]
# Удалены выбросы в 2 столбцах - общая потеря данных составляет 2.83% (283 запись).

# %%
df.describe(include=['object']).T
# Out:
#      count unique        top  freq
# city  9717      3  Ярославль  4875

# %% [markdown]
# ### Категоризация пользователей (по возрастным группам, заработной плате и по баллам кредитного скоринга)

# %%
bins = [18,35,49,59,np.inf]
df['age_cat'] = pd.cut(df['age'], bins=bins)

# %%
check_ratio('age_cat')
# Out:
#                     ratio
# age_cat      churn
# (18.0, 35.0] 0       0.92
#              1       0.08
# (35.0, 49.0] 0       0.76
#              1       0.24
# (49.0, 59.0] 0       0.44
#              1       0.56
# (59.0, inf]  0       0.57
#              1       0.43

# %% [markdown]
# Минимальный отток клиентов наблюдается в возрастной категории 18-35 лет, а максимальный - от 59 лет и выше.

# %%
df['estimated_salary_cat'] = pd.qcut(df['estimated_salary'], 4)

# %%
check_ratio('estimated_salary_cat')
# Out:
#                               ratio
# estimated_salary_cat   churn
# (11.579, 50911.41]     0       0.80
#                        1       0.20
# (50911.41, 100101.06]  0       0.80
#                        1       0.20
# (100101.06, 149381.32] 0       0.80
#                        1       0.20
# (149381.32, 199992.48] 0       0.78
#                        1       0.22

# %% [markdown]
# Максимальный отток клиентов наблюдается при зарплате свыше 149 тыс.руб., в остальных категориях доля оттока одинакова

# %%
bins = [0,500,650,690,850]
df['score_cat'] = pd.cut(df['score'], bins=bins)

# %%
check_ratio('score_cat')
# Out:
#                   ratio
# score_cat  churn
# (0, 500]   0       0.79
#            1       0.21
# (500, 650] 0       0.79
#            1       0.21
# (650, 690] 0       0.81
#            1       0.19
# (690, 850] 0       0.80
#            1       0.20

# %% [markdown]
# Минимальный отток клиентов наблюдается при score в интервале 650-690 баллов, а максимальный - при менее 500 баллах.

# %%
bins = [-9999,50000,100000,150000, 200000, np.inf]
df['balance_cat'] = pd.cut(df['balance'], bins=bins)

# %%
check_ratio('balance_cat')
# Out:
#                             ratio
# balance_cat          churn
# (-9999.0, 50000.0]   0       0.64
#                      1       0.36
# (50000.0, 100000.0]  0       0.80
#                      1       0.20
# (100000.0, 150000.0] 0       0.74
#                      1       0.26
# (150000.0, 200000.0] 0       0.78
#                      1       0.22
# (200000.0, inf]      0       0.44
#                      1       0.56

# %% [markdown]
# Минимальный отток клиентов наблюдается при балансе в интервале 50-100 тыс.руб., а максимальный - при более 200 тыс.руб..

# %%
df[['age_cat', 'score_cat', 'estimated_salary_cat', 'balance_cat' ]]=\
df[['age_cat', 'score_cat', 'estimated_salary_cat', 'balance_cat' ]].astype(str)

# %%
df.describe(include=['object'])
# Out:
#              city       age_cat estimated_salary_cat   score_cat  \
# count        9717          9717                 9717        9717
# unique          3             5                    4           4
# top     Ярославль  (35.0, 49.0]   (11.579, 50911.41]  (500, 650]
# freq         4875          4443                 2430        4192
#
#                  balance_cat
# count                   9717
# unique                     6
# top     (100000.0, 150000.0]
# freq                    3726

# %% [markdown]
# Границы интервалов для всех параметров, участвующих в категоризации выбраны методом подбора (вначале с помощью qcut параметры разбиты на 10 интервалов, а потом с учетом распределения параметров по графикам и  равной доле churn сформированы итоговые интервалы для разбиения.

# %% [markdown]
# ## Cформируем портреты клиентов

# %% [markdown]
# ### Матрица корреляций

# %%
df= pd.get_dummies(df)
df.head()
# Out:
#     user_id  score  gender  age  objects    balance  products  credit_card  \
# 0  15677338    619       0   42        2  -9,999.00         1            1
# 1  15690047    608       0   41        1  83,807.86         1            0
# 2  15662040    502       0   42        8 159,660.80         3            1
# 3  15744090    699       0   39        1  -9,999.00         2            0
# 4  15780624    850       0   43        2 125,510.82         1            1
#
#    loyalty  estimated_salary  ...  score_cat_(0, 500]  score_cat_(500, 650]  \
# 0        1        101,348.88  ...                   0                     1
# 1        1        112,542.58  ...                   0                     1
# 2        0        113,931.57  ...                   0                     1
# 3        0         93,826.63  ...                   0                     0
# 4        1         79,084.10  ...                   0                     0
#
# ...

# %%
df.columns
# Out:
# Index(['user_id', 'score', 'gender', 'age', 'objects', 'balance', 'products',
#        'credit_card', 'loyalty', 'estimated_salary', 'churn',
#        'city_Ростов Великий', 'city_Рыбинск', 'city_Ярославль',
#        'age_cat_(18.0, 35.0]', 'age_cat_(35.0, 49.0]', 'age_cat_(49.0, 59.0]',
#        'age_cat_(59.0, inf]', 'age_cat_nan',
#        'estimated_salary_cat_(100101.06, 149381.32]',
#        'estimated_salary_cat_(11.579, 50911.41]',
#        'estimated_salary_cat_(149381.32, 199992.48]',
#        'estimated_salary_cat_(50911.41, 100101.06]', 'score_cat_(0, 500]',
#        'score_cat_(500, 650]', 'score_cat_(650, 690]', 'score_cat_(690, 850]',
#        'balance_cat_(-9999.0, 50000.0]', 'balance_cat_(100000.0, 150000.0]',
#        'balance_cat_(150000.0, 200000.0]', 'balance_cat_(200000.0, inf]',
#        'balance_cat_(50000.0, 100000.0]', 'balance_cat_nan'],
#       dtype='object')

# %%
cm = df[['churn', 'score', 'gender', 'age', 'objects', 'balance', 'products',\
       'credit_card', 'loyalty', 'estimated_salary',\
       'city_Ростов Великий', 'city_Рыбинск', 'city_Ярославль']].corr()
plt.figure(figsize=(15, 10))
sns.heatmap(cm, annot = True,fmt = '0.2f', vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', linewidths=.5, linecolor='black',
           square=True)
plt.show()

# %% [markdown]
#  - мультиколлинеарность (умеренная связь) между параметрами `products` и `balance`, и `city_Ростов Великий` и `balance`
#  - на отток сильнее всего влияют:<br>
#      возраст(умеренная связь по шкале Чеддока),<br>
#      место проживания - город Ростов Великий (слабая связь),<br>
#      параметры `gender`, `balance`,`loyalty`,`city_Ростов Великий`(слабая связь).

# %% [markdown]
# ### Парные графики зависимостей переменных по оттоку

# %%
sns.pairplot(df[['score', 'gender', 'age', 'objects', 
                 'balance', 'products', 'credit_card', 'loyalty', 'churn']], hue= 'churn');

# %% [markdown]
# Клиенты, которые уходят в отток:
# - имеют 3-4 продукта,
# - возраст более 40 лет,
# - баланс близкий к нулю и более 200 тыс. руб.

# %% [markdown]
# ### Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)

# %% [markdown]
# Сформируем 2 списка из столбцов: с числовыми и с бинарными значениями

# %%
numeric = ['score', 'age', 'objects', 'balance','products', 'estimated_salary']
binar = ['credit_card', 'loyalty', 'gender']

# %%
for column in binar:
    plt.figure(figsize=(5, 5))
    sns.countplot(x = df[column], hue='churn', data=df)
    plt.title(column);

# %%
for column in numeric:
    plt.figure(figsize=(5, 5))
    sns.boxplot(x = 'churn', y = df[column], data = df)
    plt.title(column);

# %%
churn = df.groupby('churn').agg('mean').T
churn
# Out:
# churn                                                   0             1
# user_id                                     15,733,827.39 15,732,813.55
# score                                              651.40        648.03
# gender                                               0.57          0.44
# age                                                 36.40         44.42
# objects                                              5.03          4.93
# balance                                         68,974.09     88,635.85
# products                                             1.54          1.48
# credit_card                                          0.71          0.70
# loyalty                                              0.54          0.36
# estimated_salary                                99,766.85    101,105.33
# city_Ростов Великий                                  0.21          0.40
# city_Рыбинск                                         0.26          0.20
# ...

# %% [markdown]
# ### Портрет клиента, склонного к оттоку

# %% [markdown]
#  - кредитный скоринг меньше 500
#  - из Ростова Великого
#  - женщина
#  - возраст более 49 лет
#  - количество объектов недвижимости =0 или =9
#  - баланс менее 50000 руб. или более 200000 руб.
#  - продуктов больше 3
#  - активность = 0
#  - заработная плата более 150000 руб.

# %% [markdown]
# ### Портрет "хорошего" клиента

# %% [markdown]
#  - кредитный скоринг более 500
#  - из Ярославля или Рыбинска
#  - мужчина
#  - возраст до 49 лет
#  - количество объектов недвижимости =2 или =7
#  - баланс от 50000 руб. до 200000 руб.
#  - продуктов не больше 2
#  - активный
#  - заработная плата менее 150000 руб.

# %% [markdown]
# Наличие кредитной карты на портрет клиента не влияет

# %% [markdown]
# ## Проверка статистических гипотез

# %% [markdown]
# В связи с тем, что будем проверять 2 независимые группы данных, не подчиняющихся нормальному распределению, для проверки гипотез будем использовать:<br>
# критерий Манна-Уитни - для количественных переменных;<br>
# критерий хи-квадрат Пирсона - для качественных переменных.<br>
# <br>
# При проверке статистических гипотез выберем уровень значимости `alpha= 0.01` для "денежных" переменных и `alpha= 0.05`- для остальных. Проверим 7 гипотез. В связи с множественными проверками гипотез на одном и том же наборе данных растет вероятность ошибки первого рода.
# Так как задача учебная и не влияет на "реальные деньги", применим грубую поправку Бонферрони.

# %% [markdown]
# ### Гипотеза № 1: Зарплата клиентов, которые ушли в отток и тех кто остался различна

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезы так:

# %% [markdown]
# **H0: Зарплата клиентов, которые ушли в отток и тех, кто остался равна**
#
# **H1: Зарплата, которые ушли в отток и тех, кто остался различается (не равна)**

# %%
mwu_test(0.01/7, 'estimated_salary')
# Out:
# p-значение: 0.35686074991140637
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# ### Гипотеза № 2: Доли оттока клиентов в группах, имеющих 1 и 2 продукта, различаются

# %% [markdown]
# **H0: Доли оттока клиентов в группах, имеющих 1 и 2 продукта, равны**
#
# **H1: Доли оттока клиентов в группах, имеющих 1 и 2 продукта, различаются (не равны)**

# %%
df_prod=df.query('products <=2')

# %%
a = df_prod.groupby(['products','churn'])['user_id'].count()

alpha=0.05/7
kf_data = np.array([[a.loc[1,0], a.loc[1,1]], [a.loc[2,0], a.loc[2,1]]])
kf = chi2_contingency(kf_data)
print('p-значение:', kf[1])
if kf[1] < alpha:
    print("Отвергаем нулевую гипотезу")
else:
     print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 3.860131434305387e-142
# Отвергаем нулевую гипотезу

# %% [markdown]
# ### Гипотеза №3: Возраст клиентов, которые ушли в отток и тех, кто остался различен

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезы так:

# %% [markdown]
# **H0: Возраст клиентов, которые ушли в отток и тех, кто остался равен**
#
# **H1: Возраст клиентов, которые ушли в отток и тех, кто остался различается (не равен)**

# %%
mwu_test(0.05/7, 'age')
# Out:
# p-значение: 1.0509639787612928e-258
# Отвергаем нулевую гипотезу

# %% [markdown]
# ### Гипотеза № 4: Баллы кредитного скоринга клиентов, которые ушли в отток и тех, кто остался различны

# %% [markdown]
# **H0: Баллы кредитного скоринга клиентов, которые ушли в отток и тех, кто остался равны**
#
# **H1: Баллы кредитного скоринга клиентов, которые ушли в отток и тех, кто остался различаются (не равны)**

# %%
mwu_test(0.05/7, 'score')
# Out:
# p-значение: 0.14346114182625272
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# ### Гипотеза № 5: Доли мужчин и женщин, ушедших в отток и оставшихся различаются

# %% [markdown]
# **H0: Доли мужчин и женщин, ушедших в отток и оставшихся одинаковы**
#
# **H1: Доли мужчин и женщин, ушедших в отток и оставшихся различаются (не одинаковы)**

# %%
chi2(0.05/7, 'gender')
# Out:
# p-значение: 3.392790516429979e-25
# Отвергаем нулевую гипотезу

# %% [markdown]
# ### Гипотеза № 6: Баланс на счете клиентов, которые ушли в отток и тех, кто остался различен

# %% [markdown]
# **H0:  Баланс на счете клиентов, которые ушли в отток и тех, кто остался одинаков**
#
# **H1:  Баланс на счете клиентов, которые ушли в отток и тех, кто остался различается (не одинаков)**

# %%
mwu_test(0.01/7, 'balance')
# Out:
# p-значение: 1.5785761161108252e-27
# Отвергаем нулевую гипотезу

# %% [markdown]
# ### Гипотеза №7:Доли активных клиентов, которые ушли в отток и тех, кто остался различаются

# %% [markdown]
# **H0:  Доли активных клиентов, которые ушли в отток и тех, одинаковы**
#
# **H1:  Доли активных клиентов, которые ушли в отток и тех, кто остался различаются (не одинаковы)**

# %%
chi2(0.05/7, 'loyalty')
# Out:
# p-значение: 1.1160989018105298e-47
# Отвергаем нулевую гипотезу

# %%
cm = df[['gender', 'age', 'balance', 'products', 'loyalty','city_Ростов Великий',\
         'city_Рыбинск', 'city_Ярославль','churn']].corr()
plt.figure(figsize=(15, 10))
sns.heatmap(cm, annot = True,fmt = '0.2f', vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', linewidths=.5, linecolor='black',
           square=True)
plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# По параметрам: `gender`, `age`, `balance`, `products`, `loyalty` имеется статистически значимая разница между клиентами - значит они
# оказывают влияние на отток. Параметр `score`, несмотря на доминирование оттока клиентов при баллах меньше 500, не имеет статистической значимости.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# - в выборке представлены данные о 10000 уникальных клиентах, среди которых 79.6% - остались с банком, а 20.4% ушли от банка, что говорит нам о том, что данные несбалансированы;<br>
# - пропущенные значения обнаружены только в столбце `balance`;<br>
# - клиентами банка являются жители городов Ярославля (50% в выборке), Рыбинска (25%) и Ростова Великого (25%);<br>
# - данные в столбце `user_id` не несут никакой информации для анализа;<br>
# - клиенты банка имеют от 1 до 4 продуктов;<br>
# - в столбце `score` распределены люди с разным уровнем кредитного рейтинга.<br>
# <br>
# На этапе исследования выявлено:<br>
# <br>
#  - клиенты у которых score<500 уходят в отток;<br>
#  - в Рыбинске и Ярославле дела обстоят примерно одинаково, а вот в Ростове Великом % ушедших (32%)  выше, чем в других городах практически в 2 раза (16%) и практически в 1,5 раза больше, чем по всему датасету (20,4%) ;<br>
#  - женщины больше склонны к оттоку (25%), чем мужчины (16%);<br>
#  - в датасете больше 400 клиентов каждого возраста в диапазоне 31-41 год, а менее 100 клиентов в возрастных диапазонах 18-24, 53-92;<br>
#  - самый большой отток в возрасте 55 лет, клиенты от 75 лет не уходят (но есть один выброс);<br>
#  - в интервале возрастов 49-58 лет количество клиентов, ушедших в оттток, превышает число клиентов, оставшихся с банком;<br>
#  - клиенты имеют 0-10 объектов недвижимости;<br>
#  - наличие/отсутствие кредитной карты не влияет на отток;<br>
#  - разница оттока между активными клиентами (14%) и не активными клиентами (27%) составляет 13%;<br>
#   <br>
# На этапе изучения пропусков выявлено, что: <br>
# <br>
# - в Ростове Великом пропусков нет;
# - доли пропусков в Ярославле и Рыбинске практически равны и составляют 48,2% и 48,4% соответственно. <br> Наиболее вероятной причиной наличия пропусков в столбце `balance` является наличие "особого" банковского продукта, который позволяет не указывать (скрывать) баланс на счете клиента. Или связано с особенностями выгрузки данных: Ростов Великий-маленький город (30 тыс. чел) с, вероятно небольшим количеством отделений банка, а Ярославль и Рыбинск больше, население составляет 594 тыс.чел. и 197 тыс.чел. и, скорее всего, выгрузка данных клинтов из этих городов производится чаще, в несколько приемов. В одну из выгрузок и ,вероятно, "пропали(забыли выгрузить)" данные о балансе. <br>
# <br>
# На этапе категоризации выявлено, что:<br>
# <br>
#  - минимальный отток клиентов наблюдается в возрастной категории 18-35 лет, а максимальный - от 59 лет и выше;<br>
#  - максимальный отток клиентов наблюдается при зарплате свыше 149 тыс.руб.;<br>
#  - минимальный отток клиентов наблюдается при score в интервале 650-690 баллов, а максимальный - при менее 500 баллах;<br>
#  - минимальный отток клиентов наблюдается при балансе в интервале 50-100 тыс.руб., а максимальный - при более 200 тыс.руб.<br>
#  <br>
# Сформированы портреты клиентов:<br>
# *клиент, склонный к оттоку:
# <br>
#  - кредитный скоринг меньше 500<br>
#  - из Ростова Великого<br>
#  - женщина<br>
#  - возраст более 49 лет<br>
#  - количество объектов недвижимости =0 или =9<br>
#  - баланс менее 50000 руб. или более 200000 руб.<br>
#  - продуктов больше 3<br>
#  - активность = 0<br>
#  - заработная плата более 150000 руб.<br>
# <br>
# *"хороший" клиент:
# <br>
#  - кредитный скоринг более 500<br>
#  - из Ярославля или Рыбинска<br>
#  - мужчина<br>
#  - возраст до 49 лет<br>
#  - количество объектов недвижимости =2 или =7<br>
#  - баланс от 50000 руб. до 200000 руб.<br>
#  - продуктов не больше 2<br>
#  - активный<br>
#  - заработная плата менее 150000 руб.<br>
# <br>
#     По результатам проверки гипотез выявлено, что по параметрам: gender, age, balance, products, loyalty имеется статистически значимая разница между клиентами - значит они оказывают влияние на отток. Параметр score, несмотря на доминирование оттока клиентов при баллах меньше 500, не имеет статистической значимости.

# %% [markdown]
# ## Базовые рекомендации по работе с клиентами

# %% [markdown]
# - провести опрос ушедших клиентов, о причинах ухода (по звонку, по e-mail, в мессенджерах и соц.сетях). По результатам анализа причин скорректировать "политику" работы с клиентами;
# - наладить обратную связь с клиентами по улучшению продуктов и услуг банка;
# - разработать систему лояльности для удержания "хороших" клиентов,
# - для клиентов с зарплатой более 150 тыс.руб. разработать пакет "Привелегия" с уклоном на путешествия(мили, бесплатный проход в бизнес-залы аэропортов);
# - повысить осведомленность клиентов-предпенсионеров о пенсионных продуктах банка, чтобы при выходе не пенсию, они остались с банком;
# - для клиентов филиала банка в Ростове Великом предложить акцию "Переезд";
# - повысить осведомленность клиентов о продуктах банка и проводить обучение по их использованию (по e-mail, в мессенджерах и соц.сетях);
# - сравнить условия банков-конкурентов, скорректировать условия на аналогичные или лучше.
